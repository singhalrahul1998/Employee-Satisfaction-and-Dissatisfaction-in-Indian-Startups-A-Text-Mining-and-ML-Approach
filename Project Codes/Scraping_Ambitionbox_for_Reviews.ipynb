# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
#Change path as needed
path_to_chromedriver = '/Users/hp/Desktop/chromedriver/chromedriver.exe'
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# %%
#Edit URL
url = 'https://www.ambitionbox.com/reviews/indian-oil-corporation-reviews'
browser.get(url)

# %%
#Change only this portion of code
num_pages = 100
num_reviews = 998
company_code = 4

# %%
Role = []
Duration = []
Location = []
Name = []
Current_Status = []
Division = []
Overall_Satisfaction = []
Work_Life_Balance = []
Skill_Development = []
Salary_and_Benefits = []
Job_Security = []
Company_Culture = []
Career_Growth = []
Work_Satisfaction = []
Work_Detail = []
Helpful_Count = []
Views_Count = []
Date = []
Dislikes = []
Likes = []
Work_Summary = []
Other_Benefits = []
Facilities = []

# %%
for i in range(1, num_pages + 1):
    #Edit URL
    url = 'https://www.ambitionbox.com/reviews/indian-oil-corporation-reviews?page=' + str(i) + ''
    browser.get(url)
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div['+ str(j) +']/div[2]/div[1]/h2/span').text
        except NoSuchElementException:
            continue
        splittingword1 = 'For '
        splittingword2 = 'In '
        test1 = test_string.partition(splittingword1)[0]
        if (test_string == test1):
            test1 = test_string.partition(splittingword2)[0]
            test3 = ''
            test4 = test_string.partition(splittingword2)[2]
        else:    
            test2 = test_string.partition(splittingword1)[2]
            test3 = test2.partition(splittingword2)[0]
            test4 = test2.partition(splittingword2)[2]
        test1 = test1.strip()
        test3 = test3.strip()
        test4 = test4.strip()
        Role.append(test1)
        Duration.append(test3)
        Location.append(test4)
        
    
    
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[2]/div[1]/div/span[1]').text    
        except NoSuchElementException:
            continue
        splittingword1 = ' · '
        splittingword2 = ' · '
        test1 = test_string.partition(splittingword1)[0]
        test2 = test_string.partition(splittingword1)[2]
        test3 = test2.partition(splittingword2)[0]
        test4 = test2.partition(splittingword2)[2]
        test4 = test4.replace('Division', '')
        test1 = test1.strip()
        test3 = test3.strip()
        test4 = test4.strip()
        Name.append(test1)
        Current_Status.append(test3)
        Division.append(test4)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/span[1]/span').text    
        except NoSuchElementException:
            continue
        Overall_Satisfaction.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[1]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Work_Life_Balance.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[2]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Skill_Development.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[3]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Salary_and_Benefits.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[4]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Job_Security.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[5]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Company_Culture.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[6]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Career_Growth.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) +']/div[2]/div[2]/div/div[2]/div[7]/p[1]').get_attribute("innerHTML")    
        except NoSuchElementException:
            continue
        Work_Satisfaction.append(test_string)
        
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
            
        test_string_vector = []
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text) 
        except NoSuchElementException:
            if (len(Work_Detail) < num_reviews):
                Work_Detail.append('')
                test_string_vector.append('')
            continue
            
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/h3').text) 
        except NoSuchElementException:
            if (len(Work_Detail) < num_reviews):
                test_string_vector.append('')
        
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/h3').text) 
        except NoSuchElementException:
            if (len(Work_Detail) < num_reviews):
                test_string_vector.append('')
         
        count = 0
        for k in range(3):
            if (test_string_vector[k] == 'Work'):
                count = count + 1
                try:
                    test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[1]').text 
                except NoSuchElementException:
                    if (len(Work_Detail)< num_reviews):
                        Work_Detail.append('')
                        count = count + 1
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[2]').text 
                except NoSuchElementException:
                    Work_Detail.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[3]').text 
                except NoSuchElementException:
                    Work_Detail.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[4]').text 
                except NoSuchElementException:
                    Work_Detail.append(test_string)
                    continue
                Work_Detail.append(test_string)
        if count == 0:
            Work_Detail.append('')
            
            
            
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/span').text    
        except NoSuchElementException:
            if (len(Helpful_Count) < num_reviews):
                Helpful_Count.append('0')
                Views_Count.append('0')
                continue
            else:
                continue
        split = test_string.split()
        if (len(split) == 9):
            Helpful_Count.append(split[0])
            Views_Count.append(split[7])
        else:
            Helpful_Count.append('0')
            Views_Count.append(split[0])
            
            
    
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[1]/time').get_attribute('datetime')    
        except NoSuchElementException:
            continue
        Date.append(test_string)
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text 
        except NoSuchElementException:
            if (len(Dislikes) < num_reviews):
                Dislikes.append('')
            continue
        if(test_string == 'Dislikes'):
            test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/p').get_attribute('textContent') 
            Dislikes.append(test_string_content)
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/h3').text 
        except NoSuchElementException:
            if (len(Dislikes) < num_reviews):
                Dislikes.append('')
            continue
        if (test_string == 'Dislikes'):
            test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/p').get_attribute('textContent') 
            Dislikes.append(test_string_content)
            continue
        Dislikes.append('')
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text 
        except NoSuchElementException:
            if (len(Likes) < num_reviews):
                Likes.append('')
            continue
        if(test_string == 'Likes'):
            test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/p').get_attribute('textContent') 
            Likes.append(test_string_content)
            continue
        Likes.append('')
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        
        
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text 
        except NoSuchElementException:
            if (len(Work_Summary) < num_reviews):
                Work_Summary.append('')
            continue
        
        
        if(test_string == 'Work'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Work_Summary.append('')
                continue
            Work_Summary.append(test_string_content)
            continue
        
        
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/h3').text 
        except NoSuchElementException:
            if (len(Work_Summary) < num_reviews):
                Work_Summary.append('')
            continue
        
        
        if (test_string == 'Work'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Work_Summary.append('')
                continue
            Work_Summary.append(test_string_content)
            continue
        
        
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/h3').text 
        except NoSuchElementException:
            if (len(Work_Summary) < num_reviews):
                Work_Summary.append('')
            continue
        
        
        if (test_string == 'Work'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Work_Summary.append('')
                continue
            Work_Summary.append(test_string_content)
            continue
        
        
        Work_Summary.append('')
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text 
        except NoSuchElementException:
            if (len(Other_Benefits) < num_reviews):
                Other_Benefits.append('')
            continue
        if(test_string == 'Facilities'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Other_Benefits.append('')
                continue
            Other_Benefits.append(test_string_content)
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/h3').text 
        except NoSuchElementException:
            if (len(Other_Benefits) < num_reviews):
                Other_Benefits.append('')
            continue
        if (test_string == 'Facilities'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Other_Benefits.append('')
                continue
            Other_Benefits.append(test_string_content)
            continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/h3').text 
        except NoSuchElementException:
            if (len(Other_Benefits) < num_reviews):
                Other_Benefits.append('')
            continue
        if (test_string == 'Facilities'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Other_Benefits.append('')
                continue
        try:
            test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[4]/h3').text 
        except NoSuchElementException:
            if (len(Other_Benefits) < num_reviews):
                Other_Benefits.append('')
            continue
        if (test_string == 'Facilities'):
            try:
                test_string_content =  browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[4]/p').get_attribute('textContent') 
            except NoSuchElementException:
                Other_Benefits.append('')
                continue
            Other_Benefits.append(test_string_content)
            continue
            Other_Benefits.append(test_string_content)
            continue
        Other_Benefits.append('')
        
        
    for j in range(4,16):
        if (j == 6 or j == 8):
            continue
            
        test_string_vector = []
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[1]/h3').text) 
        except NoSuchElementException:
            if (len(Facilities) < num_reviews):
                Facilities.append('')
                test_string_vector.append('')
            continue
            
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[2]/h3').text) 
        except NoSuchElementException:
            if (len(Facilities) < num_reviews):
                test_string_vector.append('')
        
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[3]/h3').text) 
        except NoSuchElementException:
            if (len(Facilities) < num_reviews):
                test_string_vector.append('')
                
        try:
            test_string_vector.append(browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[4]/h3').text) 
        except NoSuchElementException:
            if (len(Facilities) < num_reviews):
                test_string_vector.append('')
         
        count = 0
        for k in range(4):
            if (test_string_vector[k] == 'Facilities'):
                count = count + 1
                try:
                    test_string = browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[1]').text 
                except NoSuchElementException:
                    if (len(Facilities)< num_reviews):
                        Facilities.append('')
                        count = count + 1
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[2]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[3]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[4]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[5]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[6]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[7]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[8]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[9]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                try:
                    test_string = test_string + ', ' + browser.find_element_by_xpath('//*[@id="all-reviews-card"]/div[' + str(j) + ']/div[3]/div[' + str(k+1) + ']/div[10]').text 
                except NoSuchElementException:
                    Facilities.append(test_string)
                    continue
                Facilities.append(test_string)
        if count == 0:
            Facilities.append('')
            
for i in range(len(Dislikes)):
    Dislikes[i] = Dislikes[i].replace('...Read More', '')
    
for i in range(len(Likes)):
    Likes[i] = Likes[i].replace('...Read More', '')
    
for i in range(len(Work_Summary)):
    Work_Summary[i] = Work_Summary[i].replace('...Read More', '')
    
for i in range(len(Other_Benefits)):
    Other_Benefits[i] = Other_Benefits[i].replace('...Read More', '')
    Other_Benefits[i] = Other_Benefits[i].replace('Other benefits - ', '')
    
for i in range(len(Facilities)):
    Facilities[i] = Facilities[i].replace('\n', ', ')

# %%
import pandas as pd
df = pd.DataFrame(list(zip(Role, Duration, Location, Name, Current_Status, Division, Overall_Satisfaction, Work_Life_Balance, Skill_Development, Salary_and_Benefits, Job_Security, Company_Culture, Career_Growth, Work_Satisfaction, Likes, Dislikes, Work_Detail, Work_Summary, Facilities, Other_Benefits, Helpful_Count, Views_Count, Date)), 
               columns = ['Role', 'Duration', 'Location', 'Name', 'Current_Status', 'Division', 'Overall_Satisfaction', 'Work_Life_Balance', 'Skill_Development', 'Salary_and_Benefits', 'Job_Security', 'Company_Culture', 'Career_Growth', 'Work_Satisfaction', 'Likes', 'Dislikes', 'Work_Detail', 'Work_Summary', 'Facilities', 'Other_Benefits', 'Helpful_Count', 'Views_Count', 'Date'])
df['Company_Code'] = company_code

# %%
#Edit name
df.to_csv('P4-IndianOilCorporation.csv')
